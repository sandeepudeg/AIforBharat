# %%
import nest_asyncio
nest_asyncio.apply()
from mcp.server import FastMCP

mcp = FastMCP("Calculator Server")

@mcp.tool(description="Add two numbers together")
def add(x: int, y: int) -> int:
    """Add two numbers and return the result."""
    return x + y
await mcp.run_streamable_http_async()

# await mcp.run(transport="streamable-http")
# Out:
# INFO:     Started server process [37488]
# INFO:     Waiting for application startup.
# [12/24/25 10:51:50] INFO     StreamableHTTP session manager started                  streamable_http_manager.py:115
# INFO:     Application startup complete.
# INFO:     Uvicorn running on http://127.0.0.1:8000 (Press CTRL+C to quit)
# INFO:     127.0.0.1:63435 - "GET / HTTP/1.1" 404 Not Found
# INFO:     127.0.0.1:63435 - "GET /favicon.ico HTTP/1.1" 404 Not Found
# INFO:     Shutting down
# INFO:     Waiting for application shutdown.
# [12/24/25 10:52:09] INFO     StreamableHTTP session manager shutting down            streamable_http_manager.py:119
# INFO:     Application shutdown complete.
# INFO:     Finished server process [37488]

# %%
from mcp.client.streamable_http import streamablehttp_client
from strands import Agent
from strands.tools.mcp.mcp_client import MCPClient

def create_streamable_http_transport():
   return streamablehttp_client("http://localhost:8000/mcp/")

streamable_http_mcp_client = MCPClient(create_streamable_http_transport)

# Use the MCP server in a context manager
with streamable_http_mcp_client:
    # Get the tools from the MCP server
    tools = streamable_http_mcp_client.list_tools_sync()
    
    # Create an agent with the MCP tools
    agent = Agent(tools=tools)
# Out:
# [12/24/25 10:55:44] ERROR    client failed to initialize                                          mcp_client.py:178
#                              ╭─────────────── Traceback (most recent call last) ────────────────╮
#                              │ d:\Learning\IITKML\Self_learning\Hack2Skills\AIForall\Workshop5\ │
#                              │ Building Agentic Workflow in                                     │
#                              │ Python\.venv\Lib\site-packages\strands\tools\mcp\mcp_client.py:1 │
#                              │ 68 in start                                                      │
#                              │                                                                  │
#                              │   165 │   │   self._log_debug_with_thread("background thread sta │
#                              │       event")                                                    │
#                              │   166 │   │   try:                                               │
#                              │   167 │   │   │   # Blocking main thread until session is initia │
#                              │       the thread stops                                           │
#                              │ ❱ 168 │   │   │   self._init_future.result(timeout=self._startup │
#                              │   169 │   │   │   self._log_debug_with_thread("the client initia │
#                              │   170 │   │   except futures.TimeoutError as e:                  │
#                              │   171 │   │   │   logger.exception("client initialization timed  │
#                              │                                                                  │
#                              │ C:\Python313\Lib\concurrent\futures\_base.py:456 in result       │
#                              │                                                                  │
#                              │   453 │   │   │   │   if self._state in [CANCELLED, CANCELLED_AN │
#                              │   454 │   │   │   │   │   raise CancelledError()                 │
#                              │   455 │   │   │   │   elif self._state == FINISHED:              │
#                              │ ❱ 456 │   │   │   │   │   return self.__get_result()             │
#                              │   457 │   │   │   │   else:                                      │
#                              │   458 │   │   │   │   │   raise TimeoutError()                   │
#                              │   459 │   │   finally:                                           │
#                              │                                                                  │
#                              │ C:\Python313\Lib\concurrent\futures\_base.py:401 in __get_result │
#                              │                                                                  │
#                              │   398 │   def __get_result(self):                                │
#                              │   399 │   │   if self._exception is not None:                    │
#                              │   400 │   │   │   try:                                           │
#                              │ ❱ 401 │   │   │   │   raise self._exception                      │
#                              │   402 │   │   │   finally:                                       │
#                              │   403 │   │   │   │   # Break a reference cycle with the excepti │
#                              │   404 │   │   │   │   self = None                                │
#                              │                                                                  │
#                              │ d:\Learning\IITKML\Self_learning\Hack2Skills\AIForall\Workshop5\ │
#                              │ Building Agentic Workflow in                                     │
#                              │ Python\.venv\Lib\site-packages\strands\tools\mcp\mcp_client.py:5 │
#                              │ 67 in _async_background_thread                                   │
#                              │                                                                  │
#                              │   564 │   │   """                                                │
#                              │   565 │   │   self._log_debug_with_thread("starting async backgr │
#                              │       connection")                                               │
#                              │   566 │   │   try:                                               │
#                              │ ❱ 567 │   │   │   async with self._transport_callable() as (read │
#                              │   568 │   │   │   │   self._log_debug_with_thread("transport con │
#                              │   569 │   │   │   │   async with ClientSession(                  │
#                              │   570 │   │   │   │   │   read_stream,                           │
#                              │                                                                  │
#                              │ C:\Python313\Lib\contextlib.py:235 in __aexit__                  │
#                              │                                                                  │
#                              │   232 │   │   │   │   # tell if we get the same exception back   │
#                              │   233 │   │   │   │   value = typ()                              │
#                              │   234 │   │   │   try:                                           │
#                              │ ❱ 235 │   │   │   │   await self.gen.athrow(value)               │
#                              │   236 │   │   │   except StopAsyncIteration as exc:              │
#                              │   237 │   │   │   │   # Suppress StopIteration *unless* it's the │
#                              │   238 │   │   │   │   # was passed to throw().  This prevents a  │
#                              │                                                                  │
#                              │ d:\Learning\IITKML\Self_learning\Hack2Skills\AIForall\Workshop5\ │
#                              │ Building Agentic Workflow in                                     │
#                              │ Python\.venv\Lib\site-packages\mcp\client\streamable_http.py:717 │
#                              │ in streamablehttp_client                                         │
#                              │                                                                  │
#                              │   714 │                                                          │
#                              │   715 │   # Manage client lifecycle since we created it          │
#                              │   716 │   async with client:                                     │
#                              │ ❱ 717 │   │   async with streamable_http_client(                 │
#                              │   718 │   │   │   url,                                           │
#                              │   719 │   │   │   http_client=client,                            │
#                              │   720 │   │   │   terminate_on_close=terminate_on_close,         │
#                              │                                                                  │
#                              │ C:\Python313\Lib\contextlib.py:235 in __aexit__                  │
#                              │                                                                  │
#                              │   232 │   │   │   │   # tell if we get the same exception back   │
#                              │   233 │   │   │   │   value = typ()                              │
#                              │   234 │   │   │   try:                                           │
#                              │ ❱ 235 │   │   │   │   await self.gen.athrow(value)               │
#                              │   236 │   │   │   except StopAsyncIteration as exc:              │
#                              │   237 │   │   │   │   # Suppress StopIteration *unless* it's the │
#                              │   238 │   │   │   │   # was passed to throw().  This prevents a  │
#                              │                                                                  │
#                              │ d:\Learning\IITKML\Self_learning\Hack2Skills\AIForall\Workshop5\ │
#                              │ Building Agentic Workflow in                                     │
#                              │ Python\.venv\Lib\site-packages\mcp\client\streamable_http.py:647 │
#                              │ in streamable_http_client                                        │
#                              │                                                                  │
#                              │   644 │                                                          │
#                              │   645 │   transport = StreamableHTTPTransport(url)               │
#                              │   646 │                                                          │
#                              │ ❱ 647 │   async with anyio.create_task_group() as tg:            │
#                              │   648 │   │   try:                                               │
#                              │   649 │   │   │   logger.debug(f"Connecting to StreamableHTTP en │
#                              │   650                                                            │
#                              │                                                                  │
#                              │ d:\Learning\IITKML\Self_learning\Hack2Skills\AIForall\Workshop5\ │
#                              │ Building Agentic Workflow in                                     │
#                              │ Python\.venv\Lib\site-packages\anyio\_backends\_asyncio.py:783   │
#                              │ in __aexit__                                                     │
#                              │                                                                  │
#                              │    780 │   │   │   │   │   # added to self._exceptions so it's o │
#                              │    781 │   │   │   │   │   # chaining and avoid adding a "During │
#                              │    782 │   │   │   │   │   # for each nesting level.             │
#                              │ ❱  783 │   │   │   │   │   raise BaseExceptionGroup(             │
#                              │    784 │   │   │   │   │   │   "unhandled errors in a TaskGroup" │
#                              │    785 │   │   │   │   │   ) from None                           │
#                              │    786 │   │   │   │   elif exc_val:                             │
#                              ╰──────────────────────────────────────────────────────────────────╯
#                              ExceptionGroup: unhandled errors in a TaskGroup (1 sub-exception)
#
#                              ╭──────────────────────── Sub-exception #1 ────────────────────────╮
#                              │ ╭───────────── Traceback (most recent call last) ──────────────╮ │
#                              │ │ C:\Python313\Lib\asyncio\tasks.py:304 in                     │ │
#                              │ │ __step_run_and_handle_result                                 │ │
#                              │ │                                                              │ │
#                              │ │    301 │   │   │   if exc is None:                           │ │
#                              │ │    302 │   │   │   │   # We use the `send` method directly,  │ │
#                              │ │    303 │   │   │   │   # don't have `__iter__` and `__next__ │ │
#                              │ │ ❱  304 │   │   │   │   result = coro.send(None)              │ │
#                              │ │    305 │   │   │   else:                                     │ │
#                              │ │    306 │   │   │   │   result = coro.throw(exc)              │ │
#                              │ │    307 │   │   except StopIteration as exc:                  │ │
#                              │ │                                                              │ │
#                              │ │ d:\Learning\IITKML\Self_learning\Hack2Skills\AIForall\Worksh │ │
#                              │ │ op5\Building Agentic Workflow in                             │ │
#                              │ │ Python\.venv\Lib\site-packages\mcp\client\streamable_http.py │ │
#                              │ │ :565 in handle_request_async                                 │ │
#                              │ │                                                              │ │
#                              │ │   562 │   │   │   │   │   │   if is_resumption:              │ │
#                              │ │   563 │   │   │   │   │   │   │   await self._handle_resumpt │ │
#                              │ │   564 │   │   │   │   │   │   else:                          │ │
#                              │ │ ❱ 565 │   │   │   │   │   │   │   await self._handle_post_re │ │
#                              │ │   566 │   │   │   │   │                                      │ │
#                              │ │   567 │   │   │   │   │   # If this is a request, start a ne │ │
#                              │ │   568 │   │   │   │   │   if isinstance(message.root, JSONRP │ │
#                              │ │                                                              │ │
#                              │ │ d:\Learning\IITKML\Self_learning\Hack2Skills\AIForall\Worksh │ │
#                              │ │ op5\Building Agentic Workflow in                             │ │
#                              │ │ Python\.venv\Lib\site-packages\mcp\client\streamable_http.py │ │
#                              │ │ :340 in _handle_post_request                                 │ │
#                              │ │                                                              │ │
#                              │ │   337 │   │   message = ctx.session_message.message          │ │
#                              │ │   338 │   │   is_initialization = self._is_initialization_re │ │
#                              │ │   339 │   │                                                  │ │
#                              │ │ ❱ 340 │   │   async with ctx.client.stream(                  │ │
#                              │ │   341 │   │   │   "POST",                                    │ │
#                              │ │   342 │   │   │   self.url,                                  │ │
#                              │ │   343 │   │   │   json=message.model_dump(by_alias=True, mod │ │
#                              │ │                                                              │ │
#                              │ │ C:\Python313\Lib\contextlib.py:214 in __aenter__             │ │
#                              │ │                                                              │ │
#                              │ │   211 │   │   # they are only needed for recreation, which i │ │
#                              │ │   212 │   │   del self.args, self.kwds, self.func            │ │
#                              │ │   213 │   │   try:                                           │ │
#                              │ │ ❱ 214 │   │   │   return await anext(self.gen)               │ │
#                              │ │   215 │   │   except StopAsyncIteration:                     │ │
#                              │ │   216 │   │   │   raise RuntimeError("generator didn't yield │ │
#                              │ │   217                                                        │ │
#                              │ │                                                              │ │
#                              │ │ d:\Learning\IITKML\Self_learning\Hack2Skills\AIForall\Worksh │ │
#                              │ │ op5\Building Agentic Workflow in                             │ │
#                              │ │ Python\.venv\Lib\site-packages\httpx\_client.py:1583 in      │ │
#                              │ │ stream                                                       │ │
#                              │ │                                                              │ │
#                              │ │   1580 │   │   │   timeout=timeout,                          │ │
#                              │ │   1581 │   │   │   extensions=extensions,                    │ │
#                              │ │   1582 │   │   )                                             │ │
#                              │ │ ❱ 1583 │   │   response = await self.send(                   │ │
#                              │ │   1584 │   │   │   request=request,                          │ │
#                              │ │   1585 │   │   │   auth=auth,                                │ │
#                              │ │   1586 │   │   │   follow_redirects=follow_redirects,        │ │
#                              │ │                                                              │ │
#                              │ │ d:\Learning\IITKML\Self_learning\Hack2Skills\AIForall\Worksh │ │
#                              │ │ op5\Building Agentic Workflow in                             │ │
#                              │ │ Python\.venv\Lib\site-packages\httpx\_client.py:1629 in send │ │
#                              │ │                                                              │ │
#                              │ │   1626 │   │                                                 │ │
#                              │ │   1627 │   │   auth = self._build_request_auth(request, auth │ │
#                              │ │   1628 │   │                                                 │ │
#                              │ │ ❱ 1629 │   │   response = await self._send_handling_auth(    │ │
#                              │ │   1630 │   │   │   request,                                  │ │
#                              │ │   1631 │   │   │   auth=auth,                                │ │
#                              │ │   1632 │   │   │   follow_redirects=follow_redirects,        │ │
#                              │ │                                                              │ │
#                              │ │ d:\Learning\IITKML\Self_learning\Hack2Skills\AIForall\Worksh │ │
#                              │ │ op5\Building Agentic Workflow in                             │ │
#                              │ │ Python\.venv\Lib\site-packages\httpx\_client.py:1657 in      │ │
#                              │ │ _send_handling_auth                                          │ │
#                              │ │                                                              │ │
#                              │ │   1654 │   │   │   request = await auth_flow.__anext__()     │ │
#                              │ │   1655 │   │   │                                             │ │
#                              │ │   1656 │   │   │   while True:                               │ │
#                              │ │ ❱ 1657 │   │   │   │   response = await self._send_handling_ │ │
#                              │ │   1658 │   │   │   │   │   request,                          │ │
#                              │ │   1659 │   │   │   │   │   follow_redirects=follow_redirects │ │
#                              │ │   1660 │   │   │   │   │   history=history,                  │ │
#                              │ │                                                              │ │
#                              │ │ d:\Learning\IITKML\Self_learning\Hack2Skills\AIForall\Worksh │ │
#                              │ │ op5\Building Agentic Workflow in                             │ │
#                              │ │ Python\.venv\Lib\site-packages\httpx\_client.py:1694 in      │ │
#                              │ │ _send_handling_redirects                                     │ │
#                              │ │                                                              │ │
#                              │ │   1691 │   │   │   for hook in self._event_hooks["request"]: │ │
#                              │ │   1692 │   │   │   │   await hook(request)                   │ │
#                              │ │   1693 │   │   │                                             │ │
#                              │ │ ❱ 1694 │   │   │   response = await self._send_single_reques │ │
#                              │ │   1695 │   │   │   try:                                      │ │
#                              │ │   1696 │   │   │   │   for hook in self._event_hooks["respon │ │
#                              │ │   1697 │   │   │   │   │   await hook(response)              │ │
#                              │ │                                                              │ │
#                              │ │ d:\Learning\IITKML\Self_learning\Hack2Skills\AIForall\Worksh │ │
#                              │ │ op5\Building Agentic Workflow in                             │ │
#                              │ │ Python\.venv\Lib\site-packages\httpx\_client.py:1730 in      │ │
#                              │ │ _send_single_request                                         │ │
#                              │ │                                                              │ │
#                              │ │   1727 │   │   │   )                                         │ │
#                              │ │   1728 │   │                                                 │ │
#                              │ │   1729 │   │   with request_context(request=request):        │ │
#                              │ │ ❱ 1730 │   │   │   response = await transport.handle_async_r │ │
#                              │ │   1731 │   │                                                 │ │
#                              │ │   1732 │   │   assert isinstance(response.stream, AsyncByteS │ │
#                              │ │   1733 │   │   response.request = request                    │ │
#                              │ │                                                              │ │
#                              │ │ d:\Learning\IITKML\Self_learning\Hack2Skills\AIForall\Worksh │ │
#                              │ │ op5\Building Agentic Workflow in                             │ │
#                              │ │ Python\.venv\Lib\site-packages\httpx\_transports\default.py: │ │
#                              │ │ 393 in handle_async_request                                  │ │
#                              │ │                                                              │ │
#                              │ │   390 │   │   │   content=request.stream,                    │ │
#                              │ │   391 │   │   │   extensions=request.extensions,             │ │
#                              │ │   392 │   │   )                                              │ │
#                              │ │ ❱ 393 │   │   with map_httpcore_exceptions():                │ │
#                              │ │   394 │   │   │   resp = await self._pool.handle_async_reque │ │
#                              │ │   395 │   │                                                  │ │
#                              │ │   396 │   │   assert isinstance(resp.stream, typing.AsyncIte │ │
#                              │ │                                                              │ │
#                              │ │ C:\Python313\Lib\contextlib.py:162 in __exit__               │ │
#                              │ │                                                              │ │
#                              │ │   159 │   │   │   │   # tell if we get the same exception ba │ │
#                              │ │   160 │   │   │   │   value = typ()                          │ │
#                              │ │   161 │   │   │   try:                                       │ │
#                              │ │ ❱ 162 │   │   │   │   self.gen.throw(value)                  │ │
#                              │ │   163 │   │   │   except StopIteration as exc:               │ │
#                              │ │   164 │   │   │   │   # Suppress StopIteration *unless* it's │ │
#                              │ │   165 │   │   │   │   # was passed to throw().  This prevent │ │
#                              │ │                                                              │ │
#                              │ │ d:\Learning\IITKML\Self_learning\Hack2Skills\AIForall\Worksh │ │
#                              │ │ op5\Building Agentic Workflow in                             │ │
#                              │ │ Python\.venv\Lib\site-packages\httpx\_transports\default.py: │ │
#                              │ │ 118 in map_httpcore_exceptions                               │ │
#                              │ │                                                              │ │
#                              │ │   115 │   │   │   raise                                      │ │
#                              │ │   116 │   │                                                  │ │
#                              │ │   117 │   │   message = str(exc)                             │ │
#                              │ │ ❱ 118 │   │   raise mapped_exc(message) from exc             │ │
#                              │ │   119                                                        │ │
#                              │ │   120                                                        │ │
#                              │ │   121 class ResponseStream(SyncByteStream):                  │ │
#                              │ ╰──────────────────────────────────────────────────────────────╯ │
#                              │ ConnectError: All connection attempts failed                     │
#                              ╰──────────────────────────────────────────────────────────────────╯
#   + Exception Group Traceback (most recent call last):
#   |   File "d:\Learning\IITKML\Self_learning\Hack2Skills\AIForall\Workshop5\Building Agentic Workflow in Python\.venv\Lib\site-packages\strands\tools\mcp\mcp_client.py", line 168, in start
#   |     self._init_future.result(timeout=self._startup_timeout)
#   |     ~~~~~~~~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   |   File "C:\Python313\Lib\concurrent\futures\_base.py", line 456, in result
#   |     return self.__get_result()
#   |            ~~~~~~~~~~~~~~~~~^^
#   |   File "C:\Python313\Lib\concurrent\futures\_base.py", line 401, in __get_result
#   |     raise self._exception
#   |   File "d:\Learning\IITKML\Self_learning\Hack2Skills\AIForall\Workshop5\Building Agentic Workflow in Python\.venv\Lib\site-packages\strands\tools\mcp\mcp_client.py", line 567, in _async_background_thread
#   |     async with self._transport_callable() as (read_stream, write_stream, *_):
#   |                ~~~~~~~~~~~~~~~~~~~~~~~~^^
#   |   File "C:\Python313\Lib\contextlib.py", line 235, in __aexit__
#   |     await self.gen.athrow(value)
#   |   File "d:\Learning\IITKML\Self_learning\Hack2Skills\AIForall\Workshop5\Building Agentic Workflow in Python\.venv\Lib\site-packages\mcp\client\streamable_http.py", line 717, in streamablehttp_client
#   |     async with streamable_http_client(
#   |                ~~~~~~~~~~~~~~~~~~~~~~^
#   |         url,
#   |         ^^^^
#   |         http_client=client,
#   |         ^^^^^^^^^^^^^^^^^^^
#   |         terminate_on_close=terminate_on_close,
#   |         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   |     ) as streams:
#   |     ^
#   |   File "C:\Python313\Lib\contextlib.py", line 235, in __aexit__
#   |     await self.gen.athrow(value)
#   |   File "d:\Learning\IITKML\Self_learning\Hack2Skills\AIForall\Workshop5\Building Agentic Workflow in Python\.venv\Lib\site-packages\mcp\client\streamable_http.py", line 647, in streamable_http_client
#   |     async with anyio.create_task_group() as tg:
#   |                ~~~~~~~~~~~~~~~~~~~~~~~^^
#   |   File "d:\Learning\IITKML\Self_learning\Hack2Skills\AIForall\Workshop5\Building Agentic Workflow in Python\.venv\Lib\site-packages\anyio\_backends\_asyncio.py", line 783, in __aexit__
#   |     raise BaseExceptionGroup(
#   |         "unhandled errors in a TaskGroup", self._exceptions
#   |     ) from None
#   | ExceptionGroup: unhandled errors in a TaskGroup (1 sub-exception)
#   +-+---------------- 1 ----------------
#     | Traceback (most recent call last):
#     |   File "d:\Learning\IITKML\Self_learning\Hack2Skills\AIForall\Workshop5\Building Agentic Workflow in Python\.venv\Lib\site-packages\httpx\_transports\default.py", line 101, in map_httpcore_exceptions
#     |     yield
#     |   File "d:\Learning\IITKML\Self_learning\Hack2Skills\AIForall\Workshop5\Building Agentic Workflow in Python\.venv\Lib\site-packages\httpx\_transports\default.py", line 394, in handle_async_request
#     |     resp = await self._pool.handle_async_request(req)
#     |            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#     |   File "d:\Learning\IITKML\Self_learning\Hack2Skills\AIForall\Workshop5\Building Agentic Workflow in Python\.venv\Lib\site-packages\httpcore\_async\connection_pool.py", line 256, in handle_async_request
#     |     raise exc from None
#     |   File "d:\Learning\IITKML\Self_learning\Hack2Skills\AIForall\Workshop5\Building Agentic Workflow in Python\.venv\Lib\site-packages\httpcore\_async\connection_pool.py", line 236, in handle_async_request
#     |     response = await connection.handle_async_request(
#     |                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#     |         pool_request.request
#     |         ^^^^^^^^^^^^^^^^^^^^
#     |     )
#     |     ^
#     |   File "d:\Learning\IITKML\Self_learning\Hack2Skills\AIForall\Workshop5\Building Agentic Workflow in Python\.venv\Lib\site-packages\httpcore\_async\connection.py", line 101, in handle_async_request
#     |     raise exc
#     |   File "d:\Learning\IITKML\Self_learning\Hack2Skills\AIForall\Workshop5\Building Agentic Workflow in Python\.venv\Lib\site-packages\httpcore\_async\connection.py", line 78, in handle_async_request
#     |     stream = await self._connect(request)
#     |              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#     |   File "d:\Learning\IITKML\Self_learning\Hack2Skills\AIForall\Workshop5\Building Agentic Workflow in Python\.venv\Lib\site-packages\httpcore\_async\connection.py", line 124, in _connect
#     |     stream = await self._network_backend.connect_tcp(**kwargs)
#     |              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#     |   File "d:\Learning\IITKML\Self_learning\Hack2Skills\AIForall\Workshop5\Building Agentic Workflow in Python\.venv\Lib\site-packages\httpcore\_backends\auto.py", line 31, in connect_tcp
#     |     return await self._backend.connect_tcp(
#     |            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#     |     ...<5 lines>...
#     |     )
#     |     ^
#     |   File "d:\Learning\IITKML\Self_learning\Hack2Skills\AIForall\Workshop5\Building Agentic Workflow in Python\.venv\Lib\site-packages\httpcore\_backends\anyio.py", line 113, in connect_tcp
#     |     with map_exceptions(exc_map):
#     |          ~~~~~~~~~~~~~~^^^^^^^^^
#     |   File "C:\Python313\Lib\contextlib.py", line 162, in __exit__
#     |     self.gen.throw(value)
#     |     ~~~~~~~~~~~~~~^^^^^^^
#     |   File "d:\Learning\IITKML\Self_learning\Hack2Skills\AIForall\Workshop5\Building Agentic Workflow in Python\.venv\Lib\site-packages\httpcore\_exceptions.py", line 14, in map_exceptions
#     |     raise to_exc(exc) from exc
#     | httpcore.ConnectError: All connection attempts failed
#     |
#     | The above exception was the direct cause of the following exception:
#     |
#     | Traceback (most recent call last):
#     |   File "C:\Python313\Lib\asyncio\tasks.py", line 304, in __step_run_and_handle_result
#     |     result = coro.send(None)
#     |   File "d:\Learning\IITKML\Self_learning\Hack2Skills\AIForall\Workshop5\Building Agentic Workflow in Python\.venv\Lib\site-packages\mcp\client\streamable_http.py", line 565, in handle_request_async
#     |     await self._handle_post_request(ctx)
#     |   File "d:\Learning\IITKML\Self_learning\Hack2Skills\AIForall\Workshop5\Building Agentic Workflow in Python\.venv\Lib\site-packages\mcp\client\streamable_http.py", line 340, in _handle_post_request
#     |     async with ctx.client.stream(
#     |                ~~~~~~~~~~~~~~~~~^
#     |         "POST",
#     |         ^^^^^^^
#     |     ...<2 lines>...
#     |         headers=headers,
#     |         ^^^^^^^^^^^^^^^^
#     |     ) as response:
#     |     ^
#     |   File "C:\Python313\Lib\contextlib.py", line 214, in __aenter__
#     |     return await anext(self.gen)
#     |            ^^^^^^^^^^^^^^^^^^^^^
#     |   File "d:\Learning\IITKML\Self_learning\Hack2Skills\AIForall\Workshop5\Building Agentic Workflow in Python\.venv\Lib\site-packages\httpx\_client.py", line 1583, in stream
#     |     response = await self.send(
#     |                ^^^^^^^^^^^^^^^^
#     |     ...<4 lines>...
#     |     )
#     |     ^
#     |   File "d:\Learning\IITKML\Self_learning\Hack2Skills\AIForall\Workshop5\Building Agentic Workflow in Python\.venv\Lib\site-packages\httpx\_client.py", line 1629, in send
#     |     response = await self._send_handling_auth(
#     |                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#     |     ...<4 lines>...
#     |     )
#     |     ^
#     |   File "d:\Learning\IITKML\Self_learning\Hack2Skills\AIForall\Workshop5\Building Agentic Workflow in Python\.venv\Lib\site-packages\httpx\_client.py", line 1657, in _send_handling_auth
#     |     response = await self._send_handling_redirects(
#     |                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#     |     ...<3 lines>...
#     |     )
#     |     ^
#     |   File "d:\Learning\IITKML\Self_learning\Hack2Skills\AIForall\Workshop5\Building Agentic Workflow in Python\.venv\Lib\site-packages\httpx\_client.py", line 1694, in _send_handling_redirects
#     |     response = await self._send_single_request(request)
#     |                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#     |   File "d:\Learning\IITKML\Self_learning\Hack2Skills\AIForall\Workshop5\Building Agentic Workflow in Python\.venv\Lib\site-packages\httpx\_client.py", line 1730, in _send_single_request
#     |     response = await transport.handle_async_request(request)
#     |                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#     |   File "d:\Learning\IITKML\Self_learning\Hack2Skills\AIForall\Workshop5\Building Agentic Workflow in Python\.venv\Lib\site-packages\httpx\_transports\default.py", line 393, in handle_async_request
#     |     with map_httpcore_exceptions():
#     |          ~~~~~~~~~~~~~~~~~~~~~~~^^
#     |   File "C:\Python313\Lib\contextlib.py", line 162, in __exit__
#     |     self.gen.throw(value)
#     |     ~~~~~~~~~~~~~~^^^^^^^
#     |   File "d:\Learning\IITKML\Self_learning\Hack2Skills\AIForall\Workshop5\Building Agentic Workflow in Python\.venv\Lib\site-packages\httpx\_transports\default.py", line 118, in map_httpcore_exceptions
#     |     raise mapped_exc(message) from exc
#     | httpx.ConnectError: All connection attempts failed
#     +------------------------------------
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "d:\Learning\IITKML\Self_learning\Hack2Skills\AIForall\Workshop5\Building Agentic Workflow in Python\.venv\Lib\site-packages\IPython\core\interactiveshell.py", line 3701, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#     ~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\sande\AppData\Local\Temp\ipykernel_37488\4061560014.py", line 11, in <module>
#     with streamable_http_mcp_client:
#          ^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "d:\Learning\IITKML\Self_learning\Hack2Skills\AIForall\Workshop5\Building Agentic Workflow in Python\.venv\Lib\site-packages\strands\tools\mcp\mcp_client.py", line 141, in __enter__
#     return self.start()
#            ~~~~~~~~~~^^
#   File "d:\Learning\IITKML\Self_learning\Hack2Skills\AIForall\Workshop5\Building Agentic Workflow in Python\.venv\Lib\site-packages\strands\tools\mcp\mcp_client.py", line 181, in start
#     raise MCPClientInitializationError("the client initialization failed") from e
# strands.types.exceptions.MCPClientInitializationError: the client initialization failed
