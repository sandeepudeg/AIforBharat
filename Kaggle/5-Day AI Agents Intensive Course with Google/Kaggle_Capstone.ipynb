# %% [markdown]
# ✅ 1. Trip Planning
#
# Suggest destinations based on user preferences (budget, season, interests).
# Create itineraries with day-by-day plans.
#
# ✅ 2. Flight & Hotel Booking
#
# Integrate with APIs like Skyscanner, Expedia, or Booking.com.
# Compare prices and availability.
# Handle multi-city or round-trip bookings.
#
# ✅ 3. Transportation Assistance
#
# Book rental cars, airport transfers, or local rides (Uber, Lyft).
# Suggest public transport routes.
#
# ✅ 4. Activity Recommendations
#
# Suggest sightseeing spots, restaurants, and local experiences.
# Book tickets for tours, events, or attractions.
#
# ✅ 5. Real-Time Updates
#
# Notify about flight delays, gate changes, or weather alerts.
# Provide currency exchange rates and local emergency info.
#
# ✅ 6. Document & Visa Assistance
#
# Remind about passport validity and visa requirements.
# Provide links to official visa application portals.
#
# ✅ 7. Budget Management
#
# Track expenses during the trip.
# Suggest cost-saving alternatives.
#
# ✅ 8. Personalized Support
#
# Store user preferences (favorite airlines, hotel chains).
# Offer loyalty program integration.
#
# ✅ 9. Emergency Contacts
#
# Provide contact details of embassy, consulate, or local police.
#
# ✅ 10. Feedback Collection
#
# Gather feedback from users after their trips.
# Improve future recommendations.
#
# ✅ 11. Travel Insurance
#
# Offer travel insurance options to users.
# Provide information on coverage and claims process.
#
# ✅ 12. Language Translation
#
# Translate text and speech for users.
# Provide language learning resources and tips.
#
# ✅ 13. Local Currency Converter
#
# Convert currencies in real-time.
# Provide ATM locations and fees.
#
# ✅ 14. Weather Forecasting
#
# Provide current and forecasted weather conditions.
#
# ✅ 15. Social Media Integration
#
# Integrate with social media platforms to share experiences and photos.
#
# ✅ 16. User Reviews & Ratings
#
# Display reviews and ratings of hotels, flights, and activities.
#
# ✅ 17. Customizable Alerts
#
# Set up alerts for flight status, hotel check-in, or activity reminders.
#
# ✅ 18. Virtual Assistant
#
# Provide assistance with booking, itinerary planning, and general travel-related queries.
#
# ✅ 19. Data Privacy & Security
#
# Ensure user data is protected and comply with privacy regulations.
#
# ✅ 20. Continuous Improvement
#
# Regularly update and improve the platform based on user feedback and technological advancements.
#
# ✅ 21. Multi-Language Support
#
# Support multiple languages for a global user base.
#
# ✅ 22. Mobile App Development
#
# Develop a mobile app for iOS and Android to provide seamless access to the platform.
#
# ✅ 23. Chatbot Integration
#
# Integrate a chatbot to provide 24/7 assistance and support to users.
#
# ✅ 24. Loyalty Program Integration
#
# Integrate with loyalty programs to offer rewards and discounts to users.
#
# ✅ 25. Collaborative Filtering
#
# Use collaborative filtering algorithms to suggest personalized recommendations based on user behavior and preferences.
#
# ✅ 26. Content-Based Filtering
#
# Use content-based filtering algorithms to suggest personalized recommendations based on user preferences and interests.
#
# ✅ 27. Natural Language Processing (NLP)
#
# Implement NLP techniques to understand and respond to natural language queries from users.
#
# ✅ 28. Image Recognition
#
# Use image recognition technology to identify and categorize images for various purposes, such as travel planning, product recommendations, or security.
#
# ✅ 29. Machine Learning Algorithms
#
# Apply machine learning algorithms to analyze user behavior, predict trends, and personalize recommendations.
#
# ✅ 30. Predictive Analytics
#
# Use predictive analytics to forecast demand and optimize inventory management.
#
# ✅ 31. Fraud Detection
#
# Implement fraud detection algorithms to protect users from fraudulent activities.
#
# ✅ 32. Augmented Reality (AR) Integration
#
# Integrate AR technology to enhance user experience and provide interactive content.
#
# ✅ 33. Voice-Activated Controls
#
# Enable voice-activated controls for hands-free interaction with the platform.
#
# ✅ 34. Gamification Elements
#
# Add gamification elements to make the travel planning process more engaging and fun.
#
# ✅ 35. Accessibility Features
#
# Ensure the platform is accessible to users with disabilities.
#
# ✅ 36. Sustainability Initiatives
#
# Implement sustainability initiatives to reduce the carbon footprint of the platform.
#
# ✅ 37. Customer Service Chatbots
#
# Implement customer service chatbots to provide 24/7 assistance and support to users.
#
# ✅ 38. Dynamic Pricing Strategies
#
# Implement dynamic pricing strategies to optimize revenue and improve user experience.
#
# ✅ 39. Personalized Marketing Campaigns
#
# Implement personalized marketing campaigns to increase user engagement and retention.
#
# ✅ 40. Internationalization Efforts
# Implement internationalization efforts to expand the platform's reach globally.
#
# ✅ 41. User-Centered Design
# Implement user-centered design principles to ensure the platform is intuitive and easy to use.
#
# ✅ 42. Scalability Measures
# Implement scalability measures to handle increased traffic and user growth.
#
# ✅ 43. Security Measures
# Implement security measures to protect user data and prevent unauthorized access.
#
# ✅ 44. Performance Optimization
# Optimize performance to ensure smooth operation and fast response times.
#
# ✅ 45. User Feedback
# Gather user feedback to improve the platform and address any issues.
#
# ✅ 46. Competitive Analysis
# Conduct competitive analysis to stay ahead of competitors and identify opportunities for improvement.
#
# ✅ 47. Continuous Improvement
# Implement continuous improvement practices to ensure the platform remains relevant and user-friendly.
# ✅ 48. Localization Efforts
# Implement localization efforts to cater to different regions and cultures.
# ✅ 49. Data Privacy and Security
# Implement data privacy and security measures to protect user information.
# ✅ 50. User Engagement Metrics
# Monitor user engagement metrics to track progress and identify areas for improvement.
# ✅ 51. SEO Optimization
# Optimize search engine visibility to attract more users.
# ✅ 52. A/B Testing
# Conduct A/B testing to compare different versions of the platform and determine which performs better.
# ✅ 53. User Retention Strategies
# Implement user retention strategies to keep users engaged and returning to the platform.
# ✅ 54. Cross-Selling Opportunities
# Identify cross-selling opportunities within the platform to increase revenue.
# ✅ 55. Platform Monetization Models
# Explore monetization models to generate revenue from the platform.
# ✅ 56. User Onboarding Process
# Design an effective user onboarding process to guide new users through the platform.
# ✅ 57. Community Building
# Encourage community building by allowing users to interact and share experiences.
# ✅ 58. Reputation Management
# Manage reputation by addressing negative feedback and improving overall user satisfaction.
# ✅ 59. Legal Compliance
# Ensure compliance with legal regulations related to travel services and data protection.
# ✅ 60. Technical Support Channels
# Establish technical support channels to assist users with any issues they may encounter while using the platform.
# ✅ 61. User Segmentation
# Segment users into different groups based on their preferences and behavior.
# ✅ 62. Personalized Notifications
# Send personalized notifications to users based on their interests and past interactions.
# ✅ 63. User Behavior Tracking
# Track user behavior to gain insights into how they interact with the platform.
# ✅ 64. User Journey Mapping
# Map out the user journey to identify pain points and areas for improvement.
# ✅ 65. Competitive Benchmarking
# Benchmark against competitors to identify gaps and opportunities for differentiation.
# ✅ 66. User Acquisition Strategies
# Develop user acquisition strategies to attract new users to the platform.
# ✅ 67. User Satisfaction Surveys
# Conduct regular surveys to gauge user satisfaction and identify areas for improvement.
# ✅ 68. User Persona Creation
# Create user personas to represent different types of users and tailor the platform accordingly.
# ✅ 69. User Lifecycle Management
# Manage the lifecycle of each user, from initial engagement to long-term retention.
# ✅ 70. User Education Resources
# Provide educational resources to help users navigate the platform effectively.
# ✅ 71. User Testimonials
# Collect testimonials from satisfied users to showcase success stories and build trust.
# ✅ 72. User Case Studies
# Share case studies that demonstrate successful outcomes achieved through the platform.
# ✅ 73. User Advocacy Programs
# Launch advocacy programs to encourage existing users to refer new users to the platform.
# ✅ 74. User Feedback Mechanisms
# Implement mechanisms for users to provide feedback and suggestions directly within the platform.
# ✅ 75. User Segmentation Analytics
# Analyze user segmentation data to inform targeted marketing and personalization efforts.
# ✅ 76. User Interaction Patterns
# Study user interaction patterns to understand how they engage with the platform.
# ✅ 77. User Experience Research
# Conduct research to gather insights into user needs, preferences, and expectations.
# ✅ 78. User Journey Optimization
# Optimize the user journey to create a seamless and enjoyable experience throughout the platform.
# ✅ 79. User Engagement KPIs
# Track key performance indicators (KPIs) to measure user engagement and satisfaction.
# ✅ 80. User Growth Strategy
# Develop a strategy to drive user growth and expansion of the platform.
# ✅ 81. User Retention Tactics
# Implement tactics to retain users and prevent churn.
# ✅ 82. User Acquisition Cost Analysis
# Analyze the cost-effectiveness of different user acquisition methods.
# ✅ 83. User Lifetime Value Calculation
# Calculate the lifetime value of each user to assess profitability.
# ✅ 84. User Attribution Modeling
# Model attribution to attribute conversions back to specific marketing channels or sources.
# ✅ 85. User Segmentation Insights
# Gain insights into user segments to inform targeted marketing campaigns.
# ✅ 86. User Retention Insights
# Analyze user retention data to identify factors that contribute to user churn.
# ✅ 87. User Acquisition Insights
# Analyze user acquisition data to identify high-performing channels and tactics.
# ✅ 88. User Engagement Insights
# Analyze user engagement data to understand how users interact with the platform.
# ✅ 89. User Feedback Insights
# Analyze user feedback to identify common pain points and areas for improvement.
# ✅ 90. User Persona Insights
# Gain insights into user personas to inform product development and marketing strategies.
# ✅ 91. User Journey Insights
# Analyze user journey data to identify friction points and opportunities for optimization.
# ✅ 92. User Acquisition Trends
# Track trends in user acquisition over time to adjust strategies accordingly.
# ✅ 93. User Retention Trends
# Track trends in user retention over time to identify potential issues early.
# ✅ 94. User Engagement Trends
# Track trends in user engagement over time to identify areas for improvement.
# ✅ 95. User Feedback Trends
# Track trends in user feedback over time to identify emerging issues or concerns.
# ✅ 96. User Persona Trends
# Track trends in user persona characteristics over time to adapt marketing strategies.
# ✅ 97. User Journey Trends
# Track trends in user journey behaviors over time to optimize the platform.
# ✅ 98. User Acquisition ROI Analysis
# Analyze return on investment (ROI) for different user acquisition channels.
# ✅ 99. User Retention ROI Analysis
# Analyze ROI for retention tactics and identify the most effective ones.
# ✅ 100. User Engagement ROI Analysis
# Analyze ROI for engagement tactics and identify the most effective ones.
# ✅ 101. User Feedback ROI Analysis
# Analyze ROI for feedback collection and implementation to improve user satisfaction.
# ✅ 102. User Persona ROI Analysis
# Analyze ROI for targeting specific user personas to maximize impact.
# ✅ 103. User Journey ROI Analysis
# Analyze ROI for optimizing the user journey to enhance user experience.
# ✅ 104. User Acquisition Cost Reduction
# Strategies to reduce costs associated with acquiring new users.
# ✅ 105. User Retention Cost Reduction
# Strategies to reduce costs associated with retaining existing users.
# ✅ 106. User Engagement Cost Reduction
# Strategies to reduce costs associated with engaging users.
# ✅ 107. User Feedback Cost Reduction
# Strategies to reduce costs associated with collecting and analyzing user feedback.
# ✅ 108. User Persona Cost Reduction
# Strategies to reduce costs associated with targeting specific user personas.
# ✅ 109. User Journey Cost Reduction
# Strategies to reduce costs associated with optimizing the user journey.
# ✅ 110. User Acquisition Efficiency Improvements
# Improving efficiency in acquiring new users through streamlined processes.
# ✅ 111. User Retention Efficiency Improvements
# Improving efficiency in retaining existing users through optimized strategies.
# ✅ 112. User Engagement Efficiency Improvements
# Improving efficiency in engaging users through optimized strategies.
# ✅ 113. User Feedback Efficiency Improvements
# Improving efficiency in collecting and analyzing user feedback through automated tools.
# ✅ 114. User Persona Efficiency Improvements
# Improving efficiency in targeting specific user personas through segmented approaches.
# ✅ 115. User Journey Efficiency Improvements
# Improving efficiency in optimizing the user journey through streamlined workflows.
# ✅ 116. User Acquisition Quality Enhancements
# Enhancing quality of acquired users through rigorous screening and verification processes.
# ✅ 117. User Retention Quality Enhancements
# Enhancing quality of retained users through personalized engagement and support.
# ✅ 118. User Engagement Quality Enhancements
# Enhancing quality of engaged users through tailored content and experiences.
# ✅ 119. User Feedback Quality Enhancements
# Enhancing quality of collected feedback through standardized protocols and validation checks.
# ✅ 120. User Persona Quality Enhancements
# Enhancing quality of targeted user personas through comprehensive profiling and segmentation.
# ✅ 121. User Journey Quality Enhancements
# Enhancing quality of the user journey through consistent branding and messaging across touchpoints.
# ✅ 122. User Acquisition Scalability Measures
# Measures to scale user acquisition without compromising quality or efficiency.
# ✅ 123. User Retention Scalability Measures
# Measures to scale user retention without compromising quality or efficiency.
# ✅ 124. User Engagement Scalability Measures
# Measures to scale user engagement without compromising quality or efficiency.
# ✅ 125. User Feedback Scalability Measures
# Measures to scale user feedback collection without compromising quality or efficiency.
# ✅ 126. User Persona Scalability Measures
# Measures to scale targeted user personas without compromising quality or efficiency.
# ✅ 127. User Journey Scalability Measures
# Measures to scale the user journey without compromising quality or efficiency.
# ✅ 128. User Acquisition Automation
# Automation of user acquisition processes to streamline operations and improve efficiency.
# ✅ 129. User Retention Automation
# Automation of user retention strategies to maintain engagement levels consistently.
# ✅ 130. User Engagement Automation
# Automation of user engagement strategies to increase interaction and loyalty.
# ✅ 131. User Feedback Automation
# Automation of user feedback collection and analysis to save time and resources.
# ✅ 132. User Persona Automation
# Automation of user persona creation and segmentation to enable targeted marketing.
# ✅ 133. User Journey Automation
# Automation of user journey optimization to enhance consistency and effectiveness.
# ✅ 134. User Acquisition Reporting
# Reporting on user acquisition performance to monitor progress and identify areas for improvement.
# ✅ 135. User Retention Reporting
# Reporting on user retention metrics to evaluate effectiveness of retention strategies.
# ✅ 136. User Engagement Reporting
# Reporting on user engagement metrics to measure interaction and loyalty.
# ✅ 137. User Feedback Reporting
# Reporting on user feedback insights to understand user sentiment and preferences.
# ✅ 138. User Persona Reporting
# Reporting on user persona characteristics to inform marketing decisions.
# ✅ 139. User Journey Reporting
# Reporting on user journey behaviors to optimize the platform.
# ✅ 140. User Acquisition Best Practices
# Best practices for acquiring new users efficiently and effectively.
# ✅ 141. User Retention Best Practices
# Best practices for retaining existing users through proactive engagement and support.
# ✅ 142. User Engagement Best Practices
# Best practices for enhancing user engagement through personalized experiences and support.

# %%
import os
from dotenv import load_dotenv
import re

load_dotenv()
api_key = os.getenv("GOOGLE_API_KEY")
if api_key:
    print("Google API key found and loaded successfully!")
else:
    print("Google API key not found get it from https://aistudio.google.com/app/api-keys")
# Out:
# Google API key found and loaded successfully!

# %%
import uuid
from google.genai import types

from google.adk.agents import LlmAgent
from google.adk.models.google_llm import Gemini
from google.adk.runners import Runner
from google.adk.sessions import InMemorySessionService

from google.adk.tools.mcp_tool.mcp_toolset import McpToolset
from google.adk.tools.tool_context import ToolContext
from google.adk.tools.mcp_tool.mcp_session_manager import StdioConnectionParams
from mcp import StdioServerParameters
from google.adk.tools import google_search, AgentTool, ToolContext
from google.adk.apps.app import App, ResumabilityConfig
from google.adk.tools.function_tool import FunctionTool
from google.adk.code_executors import BuiltInCodeExecutor
from google.adk.runners import InMemoryRunner

print("✅ ADK components imported successfully.")
# Out:
# ✅ ADK components imported successfully.

# %%
retry_config=types.HttpRetryOptions(
    attempts=5,  # Maximum retry attempts
    exp_base=7,  # Delay multiplier
    initial_delay=1,
    http_status_codes=[429, 500, 503, 504], # Retry on these HTTP errors
)

# %% [markdown]
# # Major Components of currency Agents :
# 1. Calculation Agent : This agent is responsible for performing the actual calculations required for currency conversion. calls  Currency Agent : This agent is responsible for handling the currency conversion requests and delegating the calculations to the calculation agent.

# %%
def get_fee_for_payment_method(method: str) -> dict:
    """Looks up the transaction fee percentage for a given payment method.

    This tool simulates looking up a company's internal fee structure based on
    the name of the payment method provided by the user.

    Args:
        method: The name of the payment method. It should be descriptive,
                e.g., "platinum credit card" or "bank transfer".

    Returns:
        Dictionary with status and fee information.
        Success: {"status": "success", "fee_percentage": 0.02}
        Error: {"status": "error", "error_message": "Payment method not found"}
    """
    # This simulates looking up a company's internal fee structure.
    fee_database = {
        "platinum credit card": 0.02,  # 2%
        "gold debit card": 0.035,  # 3.5%
        "bank transfer": 0.01,  # 1%
    }

    fee = fee_database.get(method.lower())
    if fee is not None:
        return {"status": "success", "fee_percentage": fee}
    else:
        return {
            "status": "error",
            "error_message": f"Payment method '{method}' not found",
        }


print("✅ Fee lookup function created")
print(f"💳 Test: {get_fee_for_payment_method('platinum credit card')}")
# Out:
# ✅ Fee lookup function created
# 💳 Test: {'status': 'success', 'fee_percentage': 0.02}

# %%
def get_exchange_rate(base_currency: str, target_currency: str) -> dict:
    """Looks up and returns the exchange rate between two currencies.

    Args:
        base_currency: The ISO 4217 currency code of the currency you
                       are converting from (e.g., "USD").
        target_currency: The ISO 4217 currency code of the currency you
                         are converting to (e.g., "EUR").

    Returns:
        Dictionary with status and rate information.
        Success: {"status": "success", "rate": 0.93}
        Error: {"status": "error", "error_message": "Unsupported currency pair"}
    """

    # Static data simulating a live exchange rate API
    # In production, this would call something like: requests.get("api.exchangerates.com")
    rate_database = {
        "usd": {
            "eur": 0.93,  # Euro
            "jpy": 157.50,  # Japanese Yen
            "inr": 83.58,  # Indian Rupee
        }
    }

    # Input validation and processing
    base = base_currency.lower()
    target = target_currency.lower()

    # Return structured result with status
    rate = rate_database.get(base, {}).get(target)
    if rate is not None:
        return {"status": "success", "rate": rate}
    else:
        return {
            "status": "error",
            "error_message": f"Unsupported currency pair: {base_currency}/{target_currency}",
        }


print("✅ Exchange rate function created")
print(f"💱 Test: {get_exchange_rate('USD', 'EUR')}")
# Out:
# ✅ Exchange rate function created
# 💱 Test: {'status': 'success', 'rate': 0.93}

# %%
calculation_agent = LlmAgent(
    name="CalculationAgent",
    model=Gemini(model="gemini-2.5-flash-lite", retry_options=retry_config),
    instruction="""You are a specialized calculator that ONLY responds with Python code. You are forbidden from providing any text, explanations, or conversational responses.
 
     Your task is to take a request for a calculation and translate it into a single block of Python code that calculates the answer.
     
     **RULES:**
    1.  Your output MUST be ONLY a Python code block.
    2.  Do NOT write any text before or after the code block.
    3.  The Python code MUST calculate the result.
    4.  The Python code MUST print the final result to stdout.
    5.  You are PROHIBITED from performing the calculation yourself. Your only job is to generate the code that will perform the calculation.
   
    Failure to follow these rules will result in an error.
       """,
    code_executor=BuiltInCodeExecutor(),  # Use the built-in Code Executor Tool. This gives the agent code execution capabilities
)

# %%
currency_agent = LlmAgent(
    name="enhanced_currency_agent",
    model=Gemini(model="gemini-2.5-flash-lite", retry_options=retry_config),
    # Updated instruction
    instruction="""You are a smart currency conversion assistant. You must strictly follow these steps and use the available tools.

  For any currency conversion request:

   1. Get Transaction Fee: Use the get_fee_for_payment_method() tool to determine the transaction fee.
   2. Get Exchange Rate: Use the get_exchange_rate() tool to get the currency conversion rate.
   3. Error Check: After each tool call, you must check the "status" field in the response. If the status is "error", you must stop and clearly explain the issue to the user.
   4. Calculate Final Amount (CRITICAL): You are strictly prohibited from performing any arithmetic calculations yourself. You must use the calculation_agent tool to generate Python code that calculates the final converted amount. This 
      code will use the fee information from step 1 and the exchange rate from step 2.
   5. Provide Detailed Breakdown: In your summary, you must:
       * State the final converted amount.
       * Explain how the result was calculated, including:
           * The fee percentage and the fee amount in the original currency.
           * The amount remaining after deducting the fee.
           * The exchange rate applied.
    """,
    tools=[
        get_fee_for_payment_method,
        get_exchange_rate,
        AgentTool(agent=calculation_agent),  # Using another agent as a tool!
    ],
)

print("✅ Enhanced currency agent created")
print("🎯 New capability: Delegates calculations to specialist agent")
print("🔧 Tool types used:")
print("  • Function Tools (fees, rates)")
print("  • Agent Tool (calculation specialist)")
# Out:
# ✅ Enhanced currency agent created
# 🎯 New capability: Delegates calculations to specialist agent
# 🔧 Tool types used:
#   • Function Tools (fees, rates)
#   • Agent Tool (calculation specialist)

# %%
enhanced_runner = InMemoryRunner(agent=currency_agent)

# %%
response = await enhanced_runner.run_debug(
    "Convert 1,250 USD to INR using a Bank Transfer. Show me the precise calculation."
)
# Out:
#  ### Created new session: debug_session_id
#
# User > Convert 1,250 USD to INR using a Bank Transfer. Show me the precise calculation.
# ...
# enhanced_currency_agent > The final amount is 103189.5 INR.
#
# Here's the breakdown of the calculation:
# *   The transaction fee for a bank transfer is 1% of the original amount, which is 12.5 USD.
# *   After deducting the fee, the amount remaining is 1237.5 USD.
# *   The exchange rate applied is 83.58 INR per USD.
# *   Therefore, the final converted amount is 1237.5 USD \* 83.58 INR/USD = 103189.5 INR.
